# %%
# Importar las librerías necesarias
import pandas as pd
import datetime
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# ##### INTR. ANÁLISIS DE DATOS (PRIMER SEMESTRE)
#
# <p style="color: #007BA7; font-size: 50px;">REGLAS DE ASOCIACIÓN: DATASET PACIENTES CON CÁNCER DE PULMÓN</p>
#
# **Felipe Sepúlveda, Diego Müller**
#
#
#
# <div style="text-align: center;">
# <img src="https://sciencemediacentre.es/sites/default/files/2023-04/c%C3%A1ncer%20pulm%C3%B3n%20ok.jpg" alt="..." width="720"/>
# </div>
#
# ---
#
# ### CONTEXTO DEL CONJUNTO DE DATOS
# Este conjunto de datos contiene información sobre la mortalidad por cáncer de pulmón. La base de datos es una colección de **información sobre pacientes diagnosticados con cáncer**. Está diseñada para el análisis de diversos factores que pueden influir en el pronóstico del cáncer y los resultados del tratamiento. La base de datos incluye **variables demográficas, médicas y relacionadas con el tratamiento, con detalles sobre la condición y la historia de cada paciente**.
#
# ### Columnas del conjunto de datos
# - **id**: Un identificador único para cada paciente en el conjunto de datos.
# - **age**: La edad del paciente en el momento del diagnóstico.
# - **gender**: El género del paciente (por ejemplo, masculino, femenino).
# - **country**: El país o región donde reside el paciente.
# - **diagnosis_date**: La fecha en que se diagnosticó al paciente con cáncer de pulmón.
# - **cancer_stage**: El estadio del cáncer de pulmón en el momento del diagnóstico (por ejemplo, Estadio I, Estadio II, Estadio III, Estadio IV).
# - **family_history**: Indica si hay antecedentes familiares de cáncer (por ejemplo, sí, no).
# - **smoking_status**: El estado de fumador del paciente (por ejemplo, fumador actual, exfumador, nunca fumó, fumador pasivo).
# - **bmi**: El Índice de Masa Corporal del paciente en el momento del diagnóstico.
# - **cholesterol_level**: El nivel de colesterol del paciente (valor).
# - **hypertension**: Indica si el paciente tiene hipertensión (presión arterial alta) (por ejemplo, sí, no).
# - **asthma**: Indica si el paciente tiene asma (por ejemplo, sí, no).
# - **cirrhosis**: Indica si el paciente tiene cirrosis hepática (por ejemplo, sí, no).
# - **other_cancer**: Indica si el paciente ha tenido algún otro tipo de cáncer además del diagnóstico principal (por ejemplo, sí, no).
# - **treatment_type**: El tipo de tratamiento que recibió el paciente (por ejemplo, cirugía, quimioterapia, radiación, combinado).
# - **end_treatment_date**: La fecha en que el paciente completó su tratamiento contra el cáncer o falleció.
# - **survived**: Indica si el paciente sobrevivió (por ejemplo, sí, no).

# %%
# Se cargan datos 
ubi= 'lung_cancer_mortality_data_small.csv'

df = pd.read_csv(ubi)
df
# Out:
#           id   age  gender     country diagnosis_date cancer_stage  \
# 0          1  64.0    Male     Croatia     2016-04-05      Stage I
# 1          2  50.0  Female       Italy     2023-04-20    Stage III
# 2          3  65.0    Male    Slovakia     2023-04-05     Stage IV
# 3          4  51.0  Female      Greece     2016-02-05    Stage III
# 4          5  37.0  Female    Slovakia     2023-11-29    Stage III
# ...      ...   ...     ...         ...            ...          ...
# 55995  55996  49.0  Female     Germany     2014-11-15    Stage III
# 55996  55997  65.0    Male  Luxembourg     2016-03-13     Stage IV
# 55997  55998  60.0  Female      Latvia     2023-05-21     Stage II
# 55998  55999  63.0  Female    Bulgaria     2015-12-09    Stage III
# 55999  56000  55.0  Female      Latvia     2015-08-09      Stage I
#
#       family_history  smoking_status   bmi  cholesterol_level  hypertension  \
# 0                Yes  Current Smoker  27.3                196             0
# 1                 No  Passive Smoker  22.4                234             1
# 2                 No   Former Smoker  20.2                210             0
# 3                Yes    Never Smoked  41.8                262             1
# 4                Yes  Passive Smoker  33.5                262             0
# ...              ...             ...   ...                ...           ...
# 55995            Yes    Never Smoked  23.6                155             0
# 55996            Yes  Current Smoker  19.6                185             0
# 55997            Yes  Passive Smoker  33.5                261             0
# 55998             No   Former Smoker  24.0                221             0
# 55999            Yes  Passive Smoker  24.3                189             1
#
#        asthma  cirrhosis  other_cancer treatment_type end_treatment_date  \
# 0           1          0             0      Radiation         2018-01-09
# 1           1          1             0   Chemotherapy         2023-11-28
# 2           0          0             0   Chemotherapy         2025-01-12
# 3           0          1             0        Surgery         2016-11-14
# 4           0          0             0   Chemotherapy         2025-03-10
# ...       ...        ...           ...            ...                ...
# 55995       0          0             0        Surgery         2016-02-13
# 55996       0          0             0       Combined         2017-11-11
# 55997       0          0             0      Radiation         2024-12-04
# 55998       0          0             0      Radiation         2017-05-10
# 55999       0          0             0      Radiation         2017-04-29
#
#        survived
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 55995         0
# 55996         0
# 55997         1
# 55998         0
# 55999         0
#
# [56000 rows x 17 columns]

# %%
# Cambiar nombre de item 0/1 
df['hypertension'] = df['hypertension'].replace({1: 'tiene hipertensión', 0: 'no tiene hipertensión'})
df['asthma'] = df['asthma'].replace({1: 'si tiene asma', 0: 'no tiene asma'})
df['cirrhosis'] = df['cirrhosis'].replace({1: 'tiene cirrosis', 0: 'no tiene cirrosis'})
df['other_cancer'] = df['other_cancer'].replace({1: 'tiene otro cáncer', 0: 'no tiene otro cáncer'})
df['survived'] = df['survived'].replace({1: 'si sobrevivió', 0: 'no sobrevivió'})

# %%
#Columnas de interés
df2_items = df[['survived', 'gender','country', 'cancer_stage','smoking_status','hypertension','asthma','cirrhosis','other_cancer','treatment_type']]
df2_items
# Out:
#             survived  gender     country cancer_stage  smoking_status  \
# 0      no sobrevivió    Male     Croatia      Stage I  Current Smoker
# 1      no sobrevivió  Female       Italy    Stage III  Passive Smoker
# 2      no sobrevivió    Male    Slovakia     Stage IV   Former Smoker
# 3      no sobrevivió  Female      Greece    Stage III    Never Smoked
# 4      no sobrevivió  Female    Slovakia    Stage III  Passive Smoker
# ...              ...     ...         ...          ...             ...
# 55995  no sobrevivió  Female     Germany    Stage III    Never Smoked
# 55996  no sobrevivió    Male  Luxembourg     Stage IV  Current Smoker
# 55997  si sobrevivió  Female      Latvia     Stage II  Passive Smoker
# 55998  no sobrevivió  Female    Bulgaria    Stage III   Former Smoker
# 55999  no sobrevivió  Female      Latvia      Stage I  Passive Smoker
#
#                 hypertension         asthma          cirrhosis  \
# 0      no tiene hipertensión  si tiene asma  no tiene cirrosis
# 1         tiene hipertensión  si tiene asma     tiene cirrosis
# 2      no tiene hipertensión  no tiene asma  no tiene cirrosis
# 3         tiene hipertensión  no tiene asma     tiene cirrosis
# 4      no tiene hipertensión  no tiene asma  no tiene cirrosis
# ...                      ...            ...                ...
# 55995  no tiene hipertensión  no tiene asma  no tiene cirrosis
# 55996  no tiene hipertensión  no tiene asma  no tiene cirrosis
# 55997  no tiene hipertensión  no tiene asma  no tiene cirrosis
# 55998  no tiene hipertensión  no tiene asma  no tiene cirrosis
# 55999     tiene hipertensión  no tiene asma  no tiene cirrosis
#
#                other_cancer treatment_type
# 0      no tiene otro cáncer      Radiation
# 1      no tiene otro cáncer   Chemotherapy
# 2      no tiene otro cáncer   Chemotherapy
# 3      no tiene otro cáncer        Surgery
# 4      no tiene otro cáncer   Chemotherapy
# ...                     ...            ...
# 55995  no tiene otro cáncer        Surgery
# 55996  no tiene otro cáncer       Combined
# 55997  no tiene otro cáncer      Radiation
# 55998  no tiene otro cáncer      Radiation
# 55999  no tiene otro cáncer      Radiation
#
# [56000 rows x 10 columns]

# %%
# paso todos los datos a un mismo tipo de dato
df3 = df2_items.astype(str)
df3
# Out:
#             survived  gender     country cancer_stage  smoking_status  \
# 0      no sobrevivió    Male     Croatia      Stage I  Current Smoker
# 1      no sobrevivió  Female       Italy    Stage III  Passive Smoker
# 2      no sobrevivió    Male    Slovakia     Stage IV   Former Smoker
# 3      no sobrevivió  Female      Greece    Stage III    Never Smoked
# 4      no sobrevivió  Female    Slovakia    Stage III  Passive Smoker
# ...              ...     ...         ...          ...             ...
# 55995  no sobrevivió  Female     Germany    Stage III    Never Smoked
# 55996  no sobrevivió    Male  Luxembourg     Stage IV  Current Smoker
# 55997  si sobrevivió  Female      Latvia     Stage II  Passive Smoker
# 55998  no sobrevivió  Female    Bulgaria    Stage III   Former Smoker
# 55999  no sobrevivió  Female      Latvia      Stage I  Passive Smoker
#
#                 hypertension         asthma          cirrhosis  \
# 0      no tiene hipertensión  si tiene asma  no tiene cirrosis
# 1         tiene hipertensión  si tiene asma     tiene cirrosis
# 2      no tiene hipertensión  no tiene asma  no tiene cirrosis
# 3         tiene hipertensión  no tiene asma     tiene cirrosis
# 4      no tiene hipertensión  no tiene asma  no tiene cirrosis
# ...                      ...            ...                ...
# 55995  no tiene hipertensión  no tiene asma  no tiene cirrosis
# 55996  no tiene hipertensión  no tiene asma  no tiene cirrosis
# 55997  no tiene hipertensión  no tiene asma  no tiene cirrosis
# 55998  no tiene hipertensión  no tiene asma  no tiene cirrosis
# 55999     tiene hipertensión  no tiene asma  no tiene cirrosis
#
#                other_cancer treatment_type
# 0      no tiene otro cáncer      Radiation
# 1      no tiene otro cáncer   Chemotherapy
# 2      no tiene otro cáncer   Chemotherapy
# 3      no tiene otro cáncer        Surgery
# 4      no tiene otro cáncer   Chemotherapy
# ...                     ...            ...
# 55995  no tiene otro cáncer        Surgery
# 55996  no tiene otro cáncer       Combined
# 55997  no tiene otro cáncer      Radiation
# 55998  no tiene otro cáncer      Radiation
# 55999  no tiene otro cáncer      Radiation
#
# [56000 rows x 10 columns]

# %%
# se crea un arreglo llamada transacciones 
transacciones=df3.values.tolist()
transacciones
# Out:
# [['no sobrevivió',
#   'Male',
#   'Croatia',
#   'Stage I',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Italy',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Slovakia',
#   'Stage IV',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Greece',
#   'Stage III',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Slovakia',
#   'Stage III',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Denmark',
#   'Stage III',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Estonia',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Ireland',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Netherlands',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Bulgaria',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Latvia',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Romania',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Hungary',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Croatia',
#   'Stage II',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Italy',
#   'Stage I',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Czech Republic',
#   'Stage IV',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Slovenia',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Austria',
#   'Stage I',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Italy',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Poland',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Finland',
#   'Stage III',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'France',
#   'Stage I',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Slovenia',
#   'Stage III',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Sweden',
#   'Stage III',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Poland',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Netherlands',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Germany',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Slovenia',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Slovenia',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Slovakia',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Bulgaria',
#   'Stage II',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Estonia',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Slovakia',
#   'Stage I',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Netherlands',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Finland',
#   'Stage I',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Austria',
#   'Stage I',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Male',
#   'Czech Republic',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Bulgaria',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Male',
#   'Greece',
#   'Stage III',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Croatia',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Czech Republic',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Spain',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Denmark',
#   'Stage II',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Portugal',
#   'Stage II',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'France',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Finland',
#   'Stage II',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Czech Republic',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Slovakia',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Poland',
#   'Stage IV',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Romania',
#   'Stage IV',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Belgium',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Slovakia',
#   'Stage III',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Germany',
#   'Stage III',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Finland',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Netherlands',
#   'Stage III',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Hungary',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Netherlands',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Portugal',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Finland',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Denmark',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Sweden',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Germany',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'France',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Estonia',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'France',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Female',
#   'France',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Poland',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Malta',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Cyprus',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Lithuania',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Sweden',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Romania',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Romania',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Spain',
#   'Stage I',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Lithuania',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Hungary',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Male',
#   'Denmark',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Cyprus',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Slovenia',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Denmark',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Portugal',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Finland',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Estonia',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Latvia',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Croatia',
#   'Stage III',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Italy',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Lithuania',
#   'Stage III',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Spain',
#   'Stage II',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Austria',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Croatia',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Female',
#   'Portugal',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Female',
#   'Estonia',
#   'Stage I',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Female',
#   'Netherlands',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Cyprus',
#   'Stage II',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Croatia',
#   'Stage IV',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Slovenia',
#   'Stage II',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Male',
#   'Germany',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Belgium',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Lithuania',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Slovenia',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Czech Republic',
#   'Stage I',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Romania',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Cyprus',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Male',
#   'Netherlands',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Poland',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Portugal',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Denmark',
#   'Stage I',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Slovenia',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Cyprus',
#   'Stage I',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Male',
#   'Romania',
#   'Stage I',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Malta',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Spain',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Netherlands',
#   'Stage I',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Slovakia',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Estonia',
#   'Stage II',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Spain',
#   'Stage I',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Austria',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Male',
#   'Poland',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Female',
#   'Cyprus',
#   'Stage II',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Sweden',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Poland',
#   'Stage II',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Czech Republic',
#   'Stage II',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Estonia',
#   'Stage I',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Portugal',
#   'Stage IV',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'France',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Male',
#   'Greece',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Romania',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Romania',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Poland',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Netherlands',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Czech Republic',
#   'Stage II',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Spain',
#   'Stage IV',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Female',
#   'Netherlands',
#   'Stage IV',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Male',
#   'Netherlands',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Germany',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Belgium',
#   'Stage II',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Poland',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Czech Republic',
#   'Stage III',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Female',
#   'Austria',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Czech Republic',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Luxembourg',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Poland',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Cyprus',
#   'Stage IV',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Croatia',
#   'Stage II',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Belgium',
#   'Stage IV',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Slovenia',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Romania',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Croatia',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Hungary',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Slovenia',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Austria',
#   'Stage I',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Italy',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Slovenia',
#   'Stage III',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Estonia',
#   'Stage III',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Italy',
#   'Stage III',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Male',
#   'Ireland',
#   'Stage II',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Italy',
#   'Stage I',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Romania',
#   'Stage II',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Finland',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Italy',
#   'Stage I',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Poland',
#   'Stage IV',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Spain',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Female',
#   'Malta',
#   'Stage II',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Netherlands',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Estonia',
#   'Stage IV',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Malta',
#   'Stage III',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Croatia',
#   'Stage II',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Female',
#   'Hungary',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Cyprus',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Hungary',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Bulgaria',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Slovenia',
#   'Stage IV',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Finland',
#   'Stage I',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Spain',
#   'Stage IV',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Germany',
#   'Stage I',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Lithuania',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Female',
#   'Latvia',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Latvia',
#   'Stage II',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Malta',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Netherlands',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Female',
#   'Austria',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Portugal',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Estonia',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Estonia',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Croatia',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Latvia',
#   'Stage II',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Croatia',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Greece',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Luxembourg',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Czech Republic',
#   'Stage II',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Austria',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Lithuania',
#   'Stage I',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Portugal',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Male',
#   'Ireland',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Slovenia',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Malta',
#   'Stage II',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Sweden',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Latvia',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Bulgaria',
#   'Stage III',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Male',
#   'Croatia',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Belgium',
#   'Stage I',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Estonia',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Germany',
#   'Stage II',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Germany',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Latvia',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'France',
#   'Stage III',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Lithuania',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Poland',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Hungary',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Spain',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Spain',
#   'Stage IV',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Belgium',
#   'Stage III',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Female',
#   'Luxembourg',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Male',
#   'Croatia',
#   'Stage IV',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Finland',
#   'Stage III',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Latvia',
#   'Stage II',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Finland',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Female',
#   'Hungary',
#   'Stage III',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Romania',
#   'Stage II',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Bulgaria',
#   'Stage I',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Estonia',
#   'Stage II',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Male',
#   'Lithuania',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Cyprus',
#   'Stage II',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Croatia',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Denmark',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Czech Republic',
#   'Stage I',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Denmark',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Female',
#   'Germany',
#   'Stage III',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Croatia',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Slovakia',
#   'Stage II',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Greece',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Denmark',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Greece',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Romania',
#   'Stage I',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Hungary',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Netherlands',
#   'Stage III',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Portugal',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Italy',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'France',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Female',
#   'Czech Republic',
#   'Stage I',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Female',
#   'Italy',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Portugal',
#   'Stage IV',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Bulgaria',
#   'Stage III',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Greece',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'France',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Slovakia',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Bulgaria',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Luxembourg',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Slovakia',
#   'Stage III',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Slovenia',
#   'Stage IV',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Slovenia',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Latvia',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Ireland',
#   'Stage I',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Portugal',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Portugal',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Netherlands',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Luxembourg',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Netherlands',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Estonia',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Sweden',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
# ...
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Lithuania',
#   'Stage I',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Slovenia',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Female',
#   'Portugal',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Bulgaria',
#   'Stage II',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Female',
#   'Hungary',
#   'Stage II',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Bulgaria',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Cyprus',
#   'Stage II',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Malta',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Bulgaria',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Spain',
#   'Stage I',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Luxembourg',
#   'Stage IV',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Finland',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Latvia',
#   'Stage IV',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Luxembourg',
#   'Stage IV',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Female',
#   'Lithuania',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Germany',
#   'Stage I',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Sweden',
#   'Stage IV',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Romania',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Denmark',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Portugal',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Male',
#   'Luxembourg',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Female',
#   'Portugal',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Belgium',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Female',
#   'Cyprus',
#   'Stage II',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Czech Republic',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Bulgaria',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Austria',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Finland',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Latvia',
#   'Stage I',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Croatia',
#   'Stage III',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Portugal',
#   'Stage I',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Denmark',
#   'Stage III',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Male',
#   'Latvia',
#   'Stage II',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Sweden',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'France',
#   'Stage I',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Hungary',
#   'Stage I',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Poland',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Romania',
#   'Stage II',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Cyprus',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Portugal',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Finland',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Hungary',
#   'Stage I',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'France',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Lithuania',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Germany',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Lithuania',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Ireland',
#   'Stage IV',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Lithuania',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Female',
#   'Cyprus',
#   'Stage IV',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Cyprus',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'France',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Czech Republic',
#   'Stage II',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Ireland',
#   'Stage I',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Spain',
#   'Stage I',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Spain',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Latvia',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Denmark',
#   'Stage II',
#   'Never Smoked',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Romania',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Malta',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Finland',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Slovenia',
#   'Stage III',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Austria',
#   'Stage I',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Female',
#   'Luxembourg',
#   'Stage I',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Poland',
#   'Stage III',
#   'Passive Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Male',
#   'Latvia',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Female',
#   'Finland',
#   'Stage I',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Female',
#   'France',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Italy',
#   'Stage III',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Denmark',
#   'Stage II',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Male',
#   'Romania',
#   'Stage IV',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Female',
#   'Slovakia',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['si sobrevivió',
#   'Male',
#   'Czech Republic',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['si sobrevivió',
#   'Male',
#   'Greece',
#   'Stage IV',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Male',
#   'Romania',
#   'Stage III',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['si sobrevivió',
#   'Female',
#   'Luxembourg',
#   'Stage I',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Czech Republic',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Female',
#   'Slovakia',
#   'Stage IV',
#   'Never Smoked',
#   'tiene hipertensión',
#   'no tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Spain',
#   'Stage III',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Radiation'],
#  ['no sobrevivió',
#   'Female',
#   'Austria',
#   'Stage II',
#   'Former Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Slovakia',
#   'Stage III',
#   'Current Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Combined'],
#  ['no sobrevivió',
#   'Male',
#   'Denmark',
#   'Stage III',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Female',
#   'Poland',
#   'Stage IV',
#   'Former Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Male',
#   'Italy',
#   'Stage II',
#   'Never Smoked',
#   'no tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ['no sobrevivió',
#   'Female',
#   'Denmark',
#   'Stage I',
#   'Current Smoker',
#   'tiene hipertensión',
#   'si tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['no sobrevivió',
#   'Female',
#   'Latvia',
#   'Stage II',
#   'Passive Smoker',
#   'tiene hipertensión',
#   'no tiene asma',
#   'no tiene cirrosis',
#   'no tiene otro cáncer',
#   'Chemotherapy'],
#  ['si sobrevivió',
#   'Male',
#   'Ireland',
#   'Stage III',
#   'Current Smoker',
#   'no tiene hipertensión',
#   'si tiene asma',
#   'tiene cirrosis',
#   'no tiene otro cáncer',
#   'Surgery'],
#  ...]

# %%
te = TransactionEncoder()

# %%
te2 = te.fit_transform(transacciones)
te2
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ...,  True,  True, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False,  True, ..., False, False, False],
#        [False, False, False, ..., False,  True, False]])

# %%
df4 = pd.DataFrame(te2, columns=te.columns_)

# Mostrar el DataFrame resultante para verificar la transformación
df4
# Out:
#        Austria  Belgium  Bulgaria  Chemotherapy  Combined  Croatia  \
# 0        False    False     False         False     False     True
# 1        False    False     False          True     False    False
# 2        False    False     False          True     False    False
# 3        False    False     False         False     False    False
# 4        False    False     False          True     False    False
# ...        ...      ...       ...           ...       ...      ...
# 55995    False    False     False         False     False    False
# 55996    False    False     False         False      True    False
# 55997    False    False     False         False     False    False
# 55998    False    False      True         False     False    False
# 55999    False    False     False         False     False    False
#
#        Current Smoker  Cyprus  Czech Republic  Denmark  ...  no sobrevivió  \
# 0                True   False           False    False  ...           True
# 1               False   False           False    False  ...           True
# 2               False   False           False    False  ...           True
# 3               False   False           False    False  ...           True
# 4               False   False           False    False  ...           True
# ...               ...     ...             ...      ...  ...            ...
# 55995           False   False           False    False  ...           True
# 55996            True   False           False    False  ...           True
# 55997           False   False           False    False  ...          False
# 55998           False   False           False    False  ...           True
# 55999           False   False           False    False  ...           True
#
#        no tiene asma  no tiene cirrosis  no tiene hipertensión  \
# 0              False               True                   True
# 1              False              False                  False
# 2               True               True                   True
# 3               True              False                  False
# 4               True               True                   True
# ...              ...                ...                    ...
# 55995           True               True                   True
# 55996           True               True                   True
# 55997           True               True                   True
# 55998           True               True                   True
# 55999           True               True                  False
#
#        no tiene otro cáncer  si sobrevivió  si tiene asma  tiene cirrosis  \
# 0                      True          False           True           False
# 1                      True          False           True            True
# 2                      True          False          False           False
# 3                      True          False          False            True
# 4                      True          False          False           False
# ...                     ...            ...            ...             ...
# 55995                  True          False          False           False
# 55996                  True          False          False           False
# 55997                  True           True          False           False
# 55998                  True          False          False           False
# 55999                  True          False          False           False
#
#        tiene hipertensión  tiene otro cáncer
# 0                   False              False
# 1                    True              False
# 2                   False              False
# 3                    True              False
# 4                   False              False
# ...                   ...                ...
# 55995               False              False
# 55996               False              False
# 55997               False              False
# 55998               False              False
# 55999                True              False
#
# [56000 rows x 51 columns]

# %%
# Calcular los ítems frecuentes utilizando el algoritmo Apriori
# Utilizamos la función apriori para encontrar ítems frecuentes en las transacciones
# - df: El DataFrame que contiene las transacciones transformadas
# - min_support=0.1: Definimos el soporte mínimo como 0.1 (10%). Esto significa que un ítem debe aparecer en al menos el 10% de las transacciones para ser considerado frecuente.
# - use_colnames=True: Usamos los nombres de las columnas (los nombres de los productos) en lugar de índices numéricos
frequent_itemsets = apriori(df4, min_support=0.2, use_colnames=True)

# Mostrar los ítems frecuentes y su soporte
print("Ítems frecuentes encontrados:")
frequent_itemsets
# Out:
# Ítems frecuentes encontrados:
#       support                                           itemsets
# 0    0.252000                                     (Chemotherapy)
# 1    0.248196                                         (Combined)
# 2    0.251000                                   (Current Smoker)
# 3    0.500232                                           (Female)
# 4    0.249518                                    (Former Smoker)
# ..        ...                                                ...
# 114  0.392821  (tiene hipertensión, no tiene otro cáncer, no ...
# 115  0.218821  (tiene hipertensión, no tiene cirrosis, si tie...
# 116  0.262161  (tiene hipertensión, no tiene otro cáncer, si ...
# 117  0.249482  (tiene hipertensión, no tiene asma, no tiene o...
# 118  0.252589  (tiene hipertensión, no tiene otro cáncer, si ...
#
# [119 rows x 2 columns]

# %%
# Generar las reglas de asociación
# Utilizamos la función association_rules para generar las reglas a partir de los ítems frecuentes.
# - frequent_itemsets: contiene los ítems frecuentes calculados con el algoritmo Apriori.
# - metric: definimos la métrica "confidence" para evaluar las reglas.
# - min_threshold: establecemos un umbral mínimo de 0.5 (50%) para la métrica de confianza.
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

# Filtrar y mostrar las reglas
# Seleccionamos las columnas más relevantes para mostrar: antecedentes, consecuentes, soporte, confianza y lift.
rules = rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
print("Reglas de asociación generadas:")
rules
# Out:
# Reglas de asociación generadas:
#                                            antecedents  \
# 0                                       (Chemotherapy)
# 1                                           (Combined)
# 2                                     (Current Smoker)
# 3                                             (Female)
# 4                                             (Female)
# ..                                                 ...
# 215  (tiene hipertensión, si tiene asma, no tiene o...
# 216  (tiene hipertensión, si tiene asma, no tiene c...
# 217  (si tiene asma, no tiene cirrosis, no tiene ot...
# 218                (tiene hipertensión, si tiene asma)
# 219                 (si tiene asma, no tiene cirrosis)
#
#                                     consequents   support  confidence  \
# 0                        (no tiene otro cáncer)  0.230196    0.913478
# 1                        (no tiene otro cáncer)  0.225411    0.908195
# 2                        (no tiene otro cáncer)  0.229518    0.914414
# 3                               (no sobrevivió)  0.389554    0.778746
# 4                           (no tiene cirrosis)  0.385250    0.770142
# ..                                          ...       ...         ...
# 215                         (no tiene cirrosis)  0.252589    0.750916
# 216                      (no tiene otro cáncer)  0.252589    0.902277
# 217                        (tiene hipertensión)  0.252589    0.793637
# 218   (no tiene cirrosis, no tiene otro cáncer)  0.252589    0.677280
# 219  (tiene hipertensión, no tiene otro cáncer)  0.252589    0.715804
#
#          lift
# 0    1.001228
# 1    0.995438
# 2    1.002254
# 3    1.001096
# 4    0.999768
# ..        ...
# 215  0.974808
# 216  0.988952
# 217  1.063832
# 218  0.959879
# 219  1.065156
#
# [220 rows x 5 columns]

# %%
# Filtrar y mostrar las reglas
# Seleccionamos solo las columnas relevantes para mostrar
rules = rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
print("Reglas de asociación generadas:")
rules
rules.to_csv('data2.csv', index=False)
# Out:
# Reglas de asociación generadas:

# %%
# Interpretación del resultado
# Iterar sobre cada regla para imprimir una interpretación más clara
for idx, rule in rules.iterrows():
    # Convertir los conjuntos de antecedentes y consecuentes en cadenas de texto
    antecedents = ', '.join(list(rule['antecedents']))
    consequents = ', '.join(list(rule['consequents']))
    support = rule['support']
    confidence = rule['confidence']
    lift = rule['lift']
    
    # Imprimir la interpretación de cada regla
    print(f"Regla: {antecedents} -> {consequents}")
    print(f"  Soporte: {support:.2f}")
    print(f"  Confianza: {confidence:.2f}")
    print(f"  Lift: {lift:.2f}")
    print(f"  Interpretación: Si un PERSONA/ESTA ES/EN {antecedents}, hay una confianza del {confidence:.2%} de que también SEA/TENGA {consequents}. El lift de {lift:.2f} indica que esta relación es {lift:.2f} veces más probable que si los HECHOS fueran independientes.\n")
# Out:
# Regla: Chemotherapy -> no tiene otro cáncer
#   Soporte: 0.23
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Chemotherapy, hay una confianza del 91.35% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Combined -> no tiene otro cáncer
#   Soporte: 0.23
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Combined, hay una confianza del 90.82% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Current Smoker -> no tiene otro cáncer
#   Soporte: 0.23
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Current Smoker, hay una confianza del 91.44% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female -> no sobrevivió
#   Soporte: 0.39
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, hay una confianza del 77.87% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female -> no tiene cirrosis
#   Soporte: 0.39
#   Confianza: 0.77
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, hay una confianza del 77.01% de que también SEA/TENGA no tiene cirrosis. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female -> no tiene otro cáncer
#   Soporte: 0.46
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, hay una confianza del 91.06% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female -> tiene hipertensión
#   Soporte: 0.37
#   Confianza: 0.75
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, hay una confianza del 74.57% de que también SEA/TENGA tiene hipertensión. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Former Smoker -> no tiene otro cáncer
#   Soporte: 0.23
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Former Smoker, hay una confianza del 91.05% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male -> no sobrevivió
#   Soporte: 0.39
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, hay una confianza del 77.70% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male -> no tiene cirrosis
#   Soporte: 0.39
#   Confianza: 0.77
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, hay una confianza del 77.05% de que también SEA/TENGA no tiene cirrosis. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male -> no tiene otro cáncer
#   Soporte: 0.46
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, hay una confianza del 91.41% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male -> tiene hipertensión
#   Soporte: 0.37
#   Confianza: 0.75
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, hay una confianza del 74.64% de que también SEA/TENGA tiene hipertensión. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Never Smoked -> no tiene otro cáncer
#   Soporte: 0.23
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Never Smoked, hay una confianza del 91.47% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Passive Smoker -> no tiene otro cáncer
#   Soporte: 0.23
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Passive Smoker, hay una confianza del 90.98% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Radiation -> no tiene otro cáncer
#   Soporte: 0.23
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Radiation, hay una confianza del 91.39% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Stage I -> no tiene otro cáncer
#   Soporte: 0.23
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Stage I, hay una confianza del 91.09% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Stage II -> no tiene otro cáncer
#   Soporte: 0.23
#   Confianza: 0.92
#   Lift: 1.01
#   Interpretación: Si un PERSONA/ESTA ES/EN Stage II, hay una confianza del 91.82% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.01 indica que esta relación es 1.01 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Stage III -> no tiene otro cáncer
#   Soporte: 0.23
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Stage III, hay una confianza del 91.05% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Stage IV -> no tiene otro cáncer
#   Soporte: 0.23
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Stage IV, hay una confianza del 90.98% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Surgery -> no tiene otro cáncer
#   Soporte: 0.23
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Surgery, hay una confianza del 91.38% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma -> no sobrevivió
#   Soporte: 0.41
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, hay una confianza del 77.80% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene cirrosis -> no sobrevivió
#   Soporte: 0.60
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene cirrosis, hay una confianza del 77.86% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no sobrevivió -> no tiene cirrosis
#   Soporte: 0.60
#   Confianza: 0.77
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no sobrevivió, hay una confianza del 77.10% de que también SEA/TENGA no tiene cirrosis. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene otro cáncer -> no sobrevivió
#   Soporte: 0.71
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene otro cáncer, hay una confianza del 77.82% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no sobrevivió -> no tiene otro cáncer
#   Soporte: 0.71
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no sobrevivió, hay una confianza del 91.27% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma -> no sobrevivió
#   Soporte: 0.37
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, hay una confianza del 77.78% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión -> no sobrevivió
#   Soporte: 0.58
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, hay una confianza del 78.07% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no sobrevivió -> tiene hipertensión
#   Soporte: 0.58
#   Confianza: 0.75
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no sobrevivió, hay una confianza del 74.87% de que también SEA/TENGA tiene hipertensión. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma -> no tiene cirrosis
#   Soporte: 0.42
#   Confianza: 0.79
#   Lift: 1.02
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, hay una confianza del 78.94% de que también SEA/TENGA no tiene cirrosis. El lift de 1.02 indica que esta relación es 1.02 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma -> no tiene otro cáncer
#   Soporte: 0.49
#   Confianza: 0.92
#   Lift: 1.01
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, hay una confianza del 92.20% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.01 indica que esta relación es 1.01 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma -> tiene hipertensión
#   Soporte: 0.37
#   Confianza: 0.71
#   Lift: 0.95
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, hay una confianza del 70.55% de que también SEA/TENGA tiene hipertensión. El lift de 0.95 indica que esta relación es 0.95 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene hipertensión -> no tiene cirrosis
#   Soporte: 0.21
#   Confianza: 0.84
#   Lift: 1.09
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene hipertensión, hay una confianza del 83.74% de que también SEA/TENGA no tiene cirrosis. El lift de 1.09 indica que esta relación es 1.09 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene otro cáncer -> no tiene cirrosis
#   Soporte: 0.71
#   Confianza: 0.77
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene otro cáncer, hay una confianza del 77.34% de que también SEA/TENGA no tiene cirrosis. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.71
#   Confianza: 0.92
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene cirrosis, hay una confianza del 91.60% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma -> no tiene cirrosis
#   Soporte: 0.35
#   Confianza: 0.75
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, hay una confianza del 74.89% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión -> no tiene cirrosis
#   Soporte: 0.56
#   Confianza: 0.75
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, hay una confianza del 74.75% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene cirrosis -> tiene hipertensión
#   Soporte: 0.56
#   Confianza: 0.72
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene cirrosis, hay una confianza del 72.39% de que también SEA/TENGA tiene hipertensión. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene hipertensión -> no tiene otro cáncer
#   Soporte: 0.24
#   Confianza: 0.95
#   Lift: 1.04
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene hipertensión, hay una confianza del 94.63% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.04 indica que esta relación es 1.04 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si sobrevivió -> no tiene otro cáncer
#   Soporte: 0.20
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN si sobrevivió, hay una confianza del 91.12% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma -> no tiene otro cáncer
#   Soporte: 0.42
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, hay una confianza del 90.15% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.21
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene cirrosis, hay una confianza del 90.02% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión -> no tiene otro cáncer
#   Soporte: 0.67
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, hay una confianza del 90.08% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene otro cáncer -> tiene hipertensión
#   Soporte: 0.67
#   Confianza: 0.74
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene otro cáncer, hay una confianza del 73.66% de que también SEA/TENGA tiene hipertensión. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma -> tiene hipertensión
#   Soporte: 0.37
#   Confianza: 0.79
#   Lift: 1.06
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, hay una confianza del 79.15% de que también SEA/TENGA tiene hipertensión. El lift de 1.06 indica que esta relación es 1.06 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, Female -> no sobrevivió
#   Soporte: 0.21
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, Female, hay una confianza del 78.07% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female, no tiene cirrosis -> no sobrevivió
#   Soporte: 0.30
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, no tiene cirrosis, hay una confianza del 77.93% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female, no sobrevivió -> no tiene cirrosis
#   Soporte: 0.30
#   Confianza: 0.77
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, no sobrevivió, hay una confianza del 77.07% de que también SEA/TENGA no tiene cirrosis. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female -> no sobrevivió, no tiene cirrosis
#   Soporte: 0.30
#   Confianza: 0.60
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, hay una confianza del 60.01% de que también SEA/TENGA no sobrevivió, no tiene cirrosis. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female, no tiene otro cáncer -> no sobrevivió
#   Soporte: 0.35
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, no tiene otro cáncer, hay una confianza del 77.83% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female, no sobrevivió -> no tiene otro cáncer
#   Soporte: 0.35
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, no sobrevivió, hay una confianza del 91.02% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female -> no sobrevivió, no tiene otro cáncer
#   Soporte: 0.35
#   Confianza: 0.71
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, hay una confianza del 70.88% de que también SEA/TENGA no sobrevivió, no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, Female -> no sobrevivió
#   Soporte: 0.29
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, Female, hay una confianza del 78.12% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female, no sobrevivió -> tiene hipertensión
#   Soporte: 0.29
#   Confianza: 0.75
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, no sobrevivió, hay una confianza del 74.80% de que también SEA/TENGA tiene hipertensión. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, Female -> no tiene cirrosis
#   Soporte: 0.21
#   Confianza: 0.79
#   Lift: 1.03
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, Female, hay una confianza del 79.02% de que también SEA/TENGA no tiene cirrosis. El lift de 1.03 indica que esta relación es 1.03 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, Female -> no tiene otro cáncer
#   Soporte: 0.24
#   Confianza: 0.92
#   Lift: 1.01
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, Female, hay una confianza del 92.00% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.01 indica que esta relación es 1.01 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female, no tiene otro cáncer -> no tiene cirrosis
#   Soporte: 0.35
#   Confianza: 0.77
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, no tiene otro cáncer, hay una confianza del 77.29% de que también SEA/TENGA no tiene cirrosis. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female, no tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.35
#   Confianza: 0.91
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, no tiene cirrosis, hay una confianza del 91.39% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female -> no tiene cirrosis, no tiene otro cáncer
#   Soporte: 0.35
#   Confianza: 0.70
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, hay una confianza del 70.38% de que también SEA/TENGA no tiene cirrosis, no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, Female -> no tiene cirrosis
#   Soporte: 0.28
#   Confianza: 0.75
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, Female, hay una confianza del 74.75% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female, no tiene cirrosis -> tiene hipertensión
#   Soporte: 0.28
#   Confianza: 0.72
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, no tiene cirrosis, hay una confianza del 72.37% de que también SEA/TENGA tiene hipertensión. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, Female -> no tiene otro cáncer
#   Soporte: 0.21
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, Female, hay una confianza del 90.01% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, Female -> no tiene otro cáncer
#   Soporte: 0.34
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, Female, hay una confianza del 90.03% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female, no tiene otro cáncer -> tiene hipertensión
#   Soporte: 0.34
#   Confianza: 0.74
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, no tiene otro cáncer, hay una confianza del 73.72% de que también SEA/TENGA tiene hipertensión. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Female -> tiene hipertensión, no tiene otro cáncer
#   Soporte: 0.34
#   Confianza: 0.67
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Female, hay una confianza del 67.13% de que también SEA/TENGA tiene hipertensión, no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, Male -> no sobrevivió
#   Soporte: 0.20
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, Male, hay una confianza del 77.52% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male, no tiene cirrosis -> no sobrevivió
#   Soporte: 0.30
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, no tiene cirrosis, hay una confianza del 77.80% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male, no sobrevivió -> no tiene cirrosis
#   Soporte: 0.30
#   Confianza: 0.77
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, no sobrevivió, hay una confianza del 77.14% de que también SEA/TENGA no tiene cirrosis. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male, no tiene otro cáncer -> no sobrevivió
#   Soporte: 0.36
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, no tiene otro cáncer, hay una confianza del 77.80% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male, no sobrevivió -> no tiene otro cáncer
#   Soporte: 0.36
#   Confianza: 0.92
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, no sobrevivió, hay una confianza del 91.53% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male -> no sobrevivió, no tiene otro cáncer
#   Soporte: 0.36
#   Confianza: 0.71
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, hay una confianza del 71.12% de que también SEA/TENGA no sobrevivió, no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, Male -> no sobrevivió
#   Soporte: 0.29
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, Male, hay una confianza del 78.02% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male, no sobrevivió -> tiene hipertensión
#   Soporte: 0.29
#   Confianza: 0.75
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, no sobrevivió, hay una confianza del 74.94% de que también SEA/TENGA tiene hipertensión. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, Male -> no tiene cirrosis
#   Soporte: 0.21
#   Confianza: 0.79
#   Lift: 1.02
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, Male, hay una confianza del 78.86% de que también SEA/TENGA no tiene cirrosis. El lift de 1.02 indica que esta relación es 1.02 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, Male -> no tiene otro cáncer
#   Soporte: 0.24
#   Confianza: 0.92
#   Lift: 1.01
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, Male, hay una confianza del 92.41% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.01 indica que esta relación es 1.01 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male, no tiene otro cáncer -> no tiene cirrosis
#   Soporte: 0.35
#   Confianza: 0.77
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, no tiene otro cáncer, hay una confianza del 77.39% de que también SEA/TENGA no tiene cirrosis. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male, no tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.35
#   Confianza: 0.92
#   Lift: 1.01
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, no tiene cirrosis, hay una confianza del 91.81% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.01 indica que esta relación es 1.01 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male -> no tiene cirrosis, no tiene otro cáncer
#   Soporte: 0.35
#   Confianza: 0.71
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, hay una confianza del 70.74% de que también SEA/TENGA no tiene cirrosis, no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, Male -> no tiene cirrosis
#   Soporte: 0.28
#   Confianza: 0.75
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, Male, hay una confianza del 74.74% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male, no tiene cirrosis -> tiene hipertensión
#   Soporte: 0.28
#   Confianza: 0.72
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, no tiene cirrosis, hay una confianza del 72.40% de que también SEA/TENGA tiene hipertensión. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, Male -> no tiene otro cáncer
#   Soporte: 0.21
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, Male, hay una confianza del 90.29% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, Male -> no tiene otro cáncer
#   Soporte: 0.34
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, Male, hay una confianza del 90.13% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male, no tiene otro cáncer -> tiene hipertensión
#   Soporte: 0.34
#   Confianza: 0.74
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, no tiene otro cáncer, hay una confianza del 73.60% de que también SEA/TENGA tiene hipertensión. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: Male -> tiene hipertensión, no tiene otro cáncer
#   Soporte: 0.34
#   Confianza: 0.67
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN Male, hay una confianza del 67.27% de que también SEA/TENGA tiene hipertensión, no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no tiene cirrosis -> no sobrevivió
#   Soporte: 0.32
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no tiene cirrosis, hay una confianza del 77.82% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no sobrevivió -> no tiene cirrosis
#   Soporte: 0.32
#   Confianza: 0.79
#   Lift: 1.02
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no sobrevivió, hay una confianza del 78.96% de que también SEA/TENGA no tiene cirrosis. El lift de 1.02 indica que esta relación es 1.02 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma -> no sobrevivió, no tiene cirrosis
#   Soporte: 0.32
#   Confianza: 0.61
#   Lift: 1.02
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, hay una confianza del 61.42% de que también SEA/TENGA no sobrevivió, no tiene cirrosis. El lift de 1.02 indica que esta relación es 1.02 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no tiene otro cáncer -> no sobrevivió
#   Soporte: 0.38
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no tiene otro cáncer, hay una confianza del 77.89% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no sobrevivió -> no tiene otro cáncer
#   Soporte: 0.38
#   Confianza: 0.92
#   Lift: 1.01
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no sobrevivió, hay una confianza del 92.31% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.01 indica que esta relación es 1.01 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma -> no sobrevivió, no tiene otro cáncer
#   Soporte: 0.38
#   Confianza: 0.72
#   Lift: 1.01
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, hay una confianza del 71.81% de que también SEA/TENGA no sobrevivió, no tiene otro cáncer. El lift de 1.01 indica que esta relación es 1.01 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene asma -> no sobrevivió
#   Soporte: 0.29
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene asma, hay una confianza del 78.14% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no sobrevivió -> tiene hipertensión
#   Soporte: 0.29
#   Confianza: 0.71
#   Lift: 0.95
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no sobrevivió, hay una confianza del 70.85% de que también SEA/TENGA tiene hipertensión. El lift de 0.95 indica que esta relación es 0.95 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene cirrosis, no tiene otro cáncer -> no sobrevivió
#   Soporte: 0.55
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene cirrosis, no tiene otro cáncer, hay una confianza del 77.93% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no sobrevivió, no tiene otro cáncer -> no tiene cirrosis
#   Soporte: 0.55
#   Confianza: 0.77
#   Lift: 1.01
#   Interpretación: Si un PERSONA/ESTA ES/EN no sobrevivió, no tiene otro cáncer, hay una confianza del 77.44% de que también SEA/TENGA no tiene cirrosis. El lift de 1.01 indica que esta relación es 1.01 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no sobrevivió, no tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.55
#   Confianza: 0.92
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no sobrevivió, no tiene cirrosis, hay una confianza del 91.67% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene otro cáncer -> no sobrevivió, no tiene cirrosis
#   Soporte: 0.55
#   Confianza: 0.60
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene otro cáncer, hay una confianza del 60.27% de que también SEA/TENGA no sobrevivió, no tiene cirrosis. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene cirrosis -> no sobrevivió, no tiene otro cáncer
#   Soporte: 0.55
#   Confianza: 0.71
#   Lift: 1.01
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene cirrosis, hay una confianza del 71.38% de que también SEA/TENGA no sobrevivió, no tiene otro cáncer. El lift de 1.01 indica que esta relación es 1.01 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no sobrevivió -> no tiene cirrosis, no tiene otro cáncer
#   Soporte: 0.55
#   Confianza: 0.71
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no sobrevivió, hay una confianza del 70.68% de que también SEA/TENGA no tiene cirrosis, no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no tiene cirrosis -> no sobrevivió
#   Soporte: 0.27
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no tiene cirrosis, hay una confianza del 77.92% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no sobrevivió -> no tiene cirrosis
#   Soporte: 0.27
#   Confianza: 0.75
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no sobrevivió, hay una confianza del 75.02% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene cirrosis -> no sobrevivió
#   Soporte: 0.44
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene cirrosis, hay una confianza del 78.14% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no sobrevivió -> no tiene cirrosis
#   Soporte: 0.44
#   Confianza: 0.75
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no sobrevivió, hay una confianza del 74.82% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no sobrevivió, no tiene cirrosis -> tiene hipertensión
#   Soporte: 0.44
#   Confianza: 0.73
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN no sobrevivió, no tiene cirrosis, hay una confianza del 72.65% de que también SEA/TENGA tiene hipertensión. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no tiene otro cáncer -> no sobrevivió
#   Soporte: 0.33
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no tiene otro cáncer, hay una confianza del 77.74% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no sobrevivió -> no tiene otro cáncer
#   Soporte: 0.33
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no sobrevivió, hay una confianza del 90.10% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma -> no sobrevivió, no tiene otro cáncer
#   Soporte: 0.33
#   Confianza: 0.70
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, hay una confianza del 70.08% de que también SEA/TENGA no sobrevivió, no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene otro cáncer -> no sobrevivió
#   Soporte: 0.52
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene otro cáncer, hay una confianza del 78.09% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no sobrevivió -> no tiene otro cáncer
#   Soporte: 0.52
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no sobrevivió, hay una confianza del 90.10% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no sobrevivió, no tiene otro cáncer -> tiene hipertensión
#   Soporte: 0.52
#   Confianza: 0.74
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN no sobrevivió, no tiene otro cáncer, hay una confianza del 73.91% de que también SEA/TENGA tiene hipertensión. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión -> no sobrevivió, no tiene otro cáncer
#   Soporte: 0.52
#   Confianza: 0.70
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, hay una confianza del 70.34% de que también SEA/TENGA no sobrevivió, no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no sobrevivió -> tiene hipertensión, no tiene otro cáncer
#   Soporte: 0.52
#   Confianza: 0.67
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no sobrevivió, hay una confianza del 67.46% de que también SEA/TENGA tiene hipertensión, no tiene otro cáncer. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, si tiene asma -> no sobrevivió
#   Soporte: 0.29
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, si tiene asma, hay una confianza del 78.00% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no sobrevivió -> tiene hipertensión
#   Soporte: 0.29
#   Confianza: 0.79
#   Lift: 1.06
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no sobrevivió, hay una confianza del 79.38% de que también SEA/TENGA tiene hipertensión. El lift de 1.06 indica que esta relación es 1.06 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma -> tiene hipertensión, no sobrevivió
#   Soporte: 0.29
#   Confianza: 0.62
#   Lift: 1.06
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, hay una confianza del 61.74% de que también SEA/TENGA tiene hipertensión, no sobrevivió. El lift de 1.06 indica que esta relación es 1.06 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no tiene otro cáncer -> no tiene cirrosis
#   Soporte: 0.39
#   Confianza: 0.79
#   Lift: 1.03
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no tiene otro cáncer, hay una confianza del 79.43% de que también SEA/TENGA no tiene cirrosis. El lift de 1.03 indica que esta relación es 1.03 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.39
#   Confianza: 0.93
#   Lift: 1.02
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no tiene cirrosis, hay una confianza del 92.78% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.02 indica que esta relación es 1.02 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma -> no tiene cirrosis, no tiene otro cáncer
#   Soporte: 0.39
#   Confianza: 0.73
#   Lift: 1.04
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, hay una confianza del 73.24% de que también SEA/TENGA no tiene cirrosis, no tiene otro cáncer. El lift de 1.04 indica que esta relación es 1.04 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene asma -> no tiene cirrosis
#   Soporte: 0.28
#   Confianza: 0.74
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene asma, hay una confianza del 74.43% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no tiene cirrosis -> tiene hipertensión
#   Soporte: 0.28
#   Confianza: 0.67
#   Lift: 0.89
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no tiene cirrosis, hay una confianza del 66.52% de que también SEA/TENGA tiene hipertensión. El lift de 0.89 indica que esta relación es 0.89 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene asma -> no tiene otro cáncer
#   Soporte: 0.34
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene asma, hay una confianza del 89.97% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no tiene otro cáncer -> tiene hipertensión
#   Soporte: 0.34
#   Confianza: 0.69
#   Lift: 0.92
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no tiene otro cáncer, hay una confianza del 68.83% de que también SEA/TENGA tiene hipertensión. El lift de 0.92 indica que esta relación es 0.92 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma -> tiene hipertensión, no tiene otro cáncer
#   Soporte: 0.34
#   Confianza: 0.63
#   Lift: 0.94
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, hay una confianza del 63.47% de que también SEA/TENGA tiene hipertensión, no tiene otro cáncer. El lift de 0.94 indica que esta relación es 0.94 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene hipertensión, no tiene otro cáncer -> no tiene cirrosis
#   Soporte: 0.20
#   Confianza: 0.85
#   Lift: 1.10
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene hipertensión, no tiene otro cáncer, hay una confianza del 84.68% de que también SEA/TENGA no tiene cirrosis. El lift de 1.10 indica que esta relación es 1.10 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene hipertensión, no tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.20
#   Confianza: 0.96
#   Lift: 1.05
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene hipertensión, no tiene cirrosis, hay una confianza del 95.68% de que también SEA/TENGA no tiene otro cáncer. El lift de 1.05 indica que esta relación es 1.05 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene hipertensión -> no tiene cirrosis, no tiene otro cáncer
#   Soporte: 0.20
#   Confianza: 0.80
#   Lift: 1.14
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene hipertensión, hay una confianza del 80.13% de que también SEA/TENGA no tiene cirrosis, no tiene otro cáncer. El lift de 1.14 indica que esta relación es 1.14 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no tiene otro cáncer -> no tiene cirrosis
#   Soporte: 0.32
#   Confianza: 0.75
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no tiene otro cáncer, hay una confianza del 74.93% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.32
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no tiene cirrosis, hay una confianza del 90.19% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma -> no tiene cirrosis, no tiene otro cáncer
#   Soporte: 0.32
#   Confianza: 0.68
#   Lift: 0.96
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, hay una confianza del 67.55% de que también SEA/TENGA no tiene cirrosis, no tiene otro cáncer. El lift de 0.96 indica que esta relación es 0.96 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene otro cáncer -> no tiene cirrosis
#   Soporte: 0.50
#   Confianza: 0.75
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene otro cáncer, hay una confianza del 74.71% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.50
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene cirrosis, hay una confianza del 90.04% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene cirrosis, no tiene otro cáncer -> tiene hipertensión
#   Soporte: 0.50
#   Confianza: 0.71
#   Lift: 0.95
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene cirrosis, no tiene otro cáncer, hay una confianza del 71.16% de que también SEA/TENGA tiene hipertensión. El lift de 0.95 indica que esta relación es 0.95 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión -> no tiene cirrosis, no tiene otro cáncer
#   Soporte: 0.50
#   Confianza: 0.67
#   Lift: 0.95
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, hay una confianza del 67.30% de que también SEA/TENGA no tiene cirrosis, no tiene otro cáncer. El lift de 0.95 indica que esta relación es 0.95 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene cirrosis -> tiene hipertensión, no tiene otro cáncer
#   Soporte: 0.50
#   Confianza: 0.65
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene cirrosis, hay una confianza del 65.18% de que también SEA/TENGA tiene hipertensión, no tiene otro cáncer. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, si tiene asma -> no tiene cirrosis
#   Soporte: 0.28
#   Confianza: 0.75
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, si tiene asma, hay una confianza del 75.06% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no tiene cirrosis -> tiene hipertensión
#   Soporte: 0.28
#   Confianza: 0.79
#   Lift: 1.06
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no tiene cirrosis, hay una confianza del 79.33% de que también SEA/TENGA tiene hipertensión. El lift de 1.06 indica que esta relación es 1.06 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, si tiene asma -> no tiene otro cáncer
#   Soporte: 0.34
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, si tiene asma, hay una confianza del 90.19% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no tiene otro cáncer -> tiene hipertensión
#   Soporte: 0.34
#   Confianza: 0.79
#   Lift: 1.06
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no tiene otro cáncer, hay una confianza del 79.19% de que también SEA/TENGA tiene hipertensión. El lift de 1.06 indica que esta relación es 1.06 veces más probable que si los HECHOS fueran independientes.
#
# ...
#
# Regla: tiene hipertensión, no tiene asma, no tiene cirrosis -> no sobrevivió
#   Soporte: 0.22
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene asma, no tiene cirrosis, hay una confianza del 78.12% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene asma, no sobrevivió -> no tiene cirrosis
#   Soporte: 0.22
#   Confianza: 0.74
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene asma, no sobrevivió, hay una confianza del 74.41% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no sobrevivió, no tiene cirrosis -> tiene hipertensión
#   Soporte: 0.22
#   Confianza: 0.67
#   Lift: 0.90
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no sobrevivió, no tiene cirrosis, hay una confianza del 66.77% de que también SEA/TENGA tiene hipertensión. El lift de 0.90 indica que esta relación es 0.90 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene asma, no tiene otro cáncer -> no sobrevivió
#   Soporte: 0.26
#   Confianza: 0.78
#   Lift: 1.01
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene asma, no tiene otro cáncer, hay una confianza del 78.24% de que también SEA/TENGA no sobrevivió. El lift de 1.01 indica que esta relación es 1.01 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene asma, no sobrevivió -> no tiene otro cáncer
#   Soporte: 0.26
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene asma, no sobrevivió, hay una confianza del 90.09% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no sobrevivió, no tiene otro cáncer -> tiene hipertensión
#   Soporte: 0.26
#   Confianza: 0.69
#   Lift: 0.93
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no sobrevivió, no tiene otro cáncer, hay una confianza del 69.15% de que también SEA/TENGA tiene hipertensión. El lift de 0.93 indica que esta relación es 0.93 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene asma -> no sobrevivió, no tiene otro cáncer
#   Soporte: 0.26
#   Confianza: 0.70
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene asma, hay una confianza del 70.39% de que también SEA/TENGA no sobrevivió, no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no sobrevivió -> tiene hipertensión, no tiene otro cáncer
#   Soporte: 0.26
#   Confianza: 0.64
#   Lift: 0.95
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no sobrevivió, hay una confianza del 63.83% de que también SEA/TENGA tiene hipertensión, no tiene otro cáncer. El lift de 0.95 indica que esta relación es 0.95 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene cirrosis, si tiene asma, no tiene otro cáncer -> no sobrevivió
#   Soporte: 0.25
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene cirrosis, si tiene asma, no tiene otro cáncer, hay una confianza del 77.95% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no sobrevivió, no tiene otro cáncer -> no tiene cirrosis
#   Soporte: 0.25
#   Confianza: 0.75
#   Lift: 0.98
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no sobrevivió, no tiene otro cáncer, hay una confianza del 75.13% de que también SEA/TENGA no tiene cirrosis. El lift de 0.98 indica que esta relación es 0.98 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no sobrevivió, no tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.25
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no sobrevivió, no tiene cirrosis, hay una confianza del 90.23% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no tiene cirrosis -> no sobrevivió, no tiene otro cáncer
#   Soporte: 0.25
#   Confianza: 0.70
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no tiene cirrosis, hay una confianza del 70.31% de que también SEA/TENGA no sobrevivió, no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no sobrevivió -> no tiene cirrosis, no tiene otro cáncer
#   Soporte: 0.25
#   Confianza: 0.68
#   Lift: 0.96
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no sobrevivió, hay una confianza del 67.69% de que también SEA/TENGA no tiene cirrosis, no tiene otro cáncer. El lift de 0.96 indica que esta relación es 0.96 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene cirrosis, no tiene otro cáncer -> no sobrevivió
#   Soporte: 0.39
#   Confianza: 0.78
#   Lift: 1.01
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene cirrosis, no tiene otro cáncer, hay una confianza del 78.24% de que también SEA/TENGA no sobrevivió. El lift de 1.01 indica que esta relación es 1.01 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no sobrevivió, no tiene otro cáncer -> no tiene cirrosis
#   Soporte: 0.39
#   Confianza: 0.75
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no sobrevivió, no tiene otro cáncer, hay una confianza del 74.86% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no sobrevivió, no tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.39
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no sobrevivió, no tiene cirrosis, hay una confianza del 90.15% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene cirrosis, no sobrevivió, no tiene otro cáncer -> tiene hipertensión
#   Soporte: 0.39
#   Confianza: 0.71
#   Lift: 0.96
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene cirrosis, no sobrevivió, no tiene otro cáncer, hay una confianza del 71.44% de que también SEA/TENGA tiene hipertensión. El lift de 0.96 indica que esta relación es 0.96 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene cirrosis -> no sobrevivió, no tiene otro cáncer
#   Soporte: 0.39
#   Confianza: 0.70
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene cirrosis, hay una confianza del 70.45% de que también SEA/TENGA no sobrevivió, no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no sobrevivió -> no tiene cirrosis, no tiene otro cáncer
#   Soporte: 0.39
#   Confianza: 0.67
#   Lift: 0.96
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no sobrevivió, hay una confianza del 67.45% de que también SEA/TENGA no tiene cirrosis, no tiene otro cáncer. El lift de 0.96 indica que esta relación es 0.96 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no sobrevivió, no tiene cirrosis -> tiene hipertensión, no tiene otro cáncer
#   Soporte: 0.39
#   Confianza: 0.65
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN no sobrevivió, no tiene cirrosis, hay una confianza del 65.49% de que también SEA/TENGA tiene hipertensión, no tiene otro cáncer. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, si tiene asma, no tiene cirrosis -> no sobrevivió
#   Soporte: 0.22
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, si tiene asma, no tiene cirrosis, hay una confianza del 78.17% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, si tiene asma, no sobrevivió -> no tiene cirrosis
#   Soporte: 0.22
#   Confianza: 0.75
#   Lift: 0.98
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, si tiene asma, no sobrevivió, hay una confianza del 75.22% de que también SEA/TENGA no tiene cirrosis. El lift de 0.98 indica que esta relación es 0.98 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no sobrevivió, no tiene cirrosis -> tiene hipertensión
#   Soporte: 0.22
#   Confianza: 0.80
#   Lift: 1.07
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no sobrevivió, no tiene cirrosis, hay una confianza del 79.59% de que también SEA/TENGA tiene hipertensión. El lift de 1.07 indica que esta relación es 1.07 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no tiene cirrosis -> tiene hipertensión, no sobrevivió
#   Soporte: 0.22
#   Confianza: 0.62
#   Lift: 1.06
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no tiene cirrosis, hay una confianza del 62.01% de que también SEA/TENGA tiene hipertensión, no sobrevivió. El lift de 1.06 indica que esta relación es 1.06 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, si tiene asma, no tiene otro cáncer -> no sobrevivió
#   Soporte: 0.26
#   Confianza: 0.78
#   Lift: 1.00
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, si tiene asma, no tiene otro cáncer, hay una confianza del 77.94% de que también SEA/TENGA no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, si tiene asma, no sobrevivió -> no tiene otro cáncer
#   Soporte: 0.26
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, si tiene asma, no sobrevivió, hay una confianza del 90.12% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no sobrevivió, no tiene otro cáncer -> tiene hipertensión
#   Soporte: 0.26
#   Confianza: 0.79
#   Lift: 1.06
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no sobrevivió, no tiene otro cáncer, hay una confianza del 79.40% de que también SEA/TENGA tiene hipertensión. El lift de 1.06 indica que esta relación es 1.06 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, si tiene asma -> no sobrevivió, no tiene otro cáncer
#   Soporte: 0.26
#   Confianza: 0.70
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, si tiene asma, hay una confianza del 70.29% de que también SEA/TENGA no sobrevivió, no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no tiene otro cáncer -> tiene hipertensión, no sobrevivió
#   Soporte: 0.26
#   Confianza: 0.62
#   Lift: 1.06
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no tiene otro cáncer, hay una confianza del 61.72% de que también SEA/TENGA tiene hipertensión, no sobrevivió. El lift de 1.06 indica que esta relación es 1.06 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no sobrevivió -> tiene hipertensión, no tiene otro cáncer
#   Soporte: 0.26
#   Confianza: 0.72
#   Lift: 1.06
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no sobrevivió, hay una confianza del 71.53% de que también SEA/TENGA tiene hipertensión, no tiene otro cáncer. El lift de 1.06 indica que esta relación es 1.06 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene asma, no tiene otro cáncer -> no tiene cirrosis
#   Soporte: 0.25
#   Confianza: 0.74
#   Lift: 0.96
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene asma, no tiene otro cáncer, hay una confianza del 74.33% de que también SEA/TENGA no tiene cirrosis. El lift de 0.96 indica que esta relación es 0.96 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene asma, no tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.25
#   Confianza: 0.90
#   Lift: 0.98
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene asma, no tiene cirrosis, hay una confianza del 89.85% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.98 indica que esta relación es 0.98 veces más probable que si los HECHOS fueran independientes.
#
# Regla: no tiene asma, no tiene cirrosis, no tiene otro cáncer -> tiene hipertensión
#   Soporte: 0.25
#   Confianza: 0.64
#   Lift: 0.86
#   Interpretación: Si un PERSONA/ESTA ES/EN no tiene asma, no tiene cirrosis, no tiene otro cáncer, hay una confianza del 64.41% de que también SEA/TENGA tiene hipertensión. El lift de 0.86 indica que esta relación es 0.86 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, no tiene asma -> no tiene cirrosis, no tiene otro cáncer
#   Soporte: 0.25
#   Confianza: 0.67
#   Lift: 0.95
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, no tiene asma, hay una confianza del 66.87% de que también SEA/TENGA no tiene cirrosis, no tiene otro cáncer. El lift de 0.95 indica que esta relación es 0.95 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, si tiene asma, no tiene otro cáncer -> no tiene cirrosis
#   Soporte: 0.25
#   Confianza: 0.75
#   Lift: 0.97
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, si tiene asma, no tiene otro cáncer, hay una confianza del 75.09% de que también SEA/TENGA no tiene cirrosis. El lift de 0.97 indica que esta relación es 0.97 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, si tiene asma, no tiene cirrosis -> no tiene otro cáncer
#   Soporte: 0.25
#   Confianza: 0.90
#   Lift: 0.99
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, si tiene asma, no tiene cirrosis, hay una confianza del 90.23% de que también SEA/TENGA no tiene otro cáncer. El lift de 0.99 indica que esta relación es 0.99 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no tiene cirrosis, no tiene otro cáncer -> tiene hipertensión
#   Soporte: 0.25
#   Confianza: 0.79
#   Lift: 1.06
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no tiene cirrosis, no tiene otro cáncer, hay una confianza del 79.36% de que también SEA/TENGA tiene hipertensión. El lift de 1.06 indica que esta relación es 1.06 veces más probable que si los HECHOS fueran independientes.
#
# Regla: tiene hipertensión, si tiene asma -> no tiene cirrosis, no tiene otro cáncer
#   Soporte: 0.25
#   Confianza: 0.68
#   Lift: 0.96
#   Interpretación: Si un PERSONA/ESTA ES/EN tiene hipertensión, si tiene asma, hay una confianza del 67.73% de que también SEA/TENGA no tiene cirrosis, no tiene otro cáncer. El lift de 0.96 indica que esta relación es 0.96 veces más probable que si los HECHOS fueran independientes.
#
# Regla: si tiene asma, no tiene cirrosis -> tiene hipertensión, no tiene otro cáncer
#   Soporte: 0.25
#   Confianza: 0.72
#   Lift: 1.07
#   Interpretación: Si un PERSONA/ESTA ES/EN si tiene asma, no tiene cirrosis, hay una confianza del 71.58% de que también SEA/TENGA tiene hipertensión, no tiene otro cáncer. El lift de 1.07 indica que esta relación es 1.07 veces más probable que si los HECHOS fueran independientes.

# %% [markdown]
# ### **HIPÓTESIS**: ¿UN INDIVIDUO CON ASMA SOBREVIVE A UN CÁNCER DE PULMÓN?
#
# #### REGLAS DE ASOCIACIÓN
#
# ![...](asmasobr.png)
#
# **Regla: tiene asma -> no sobrevivió**
# - **Soporte**: 0.37
# - **Confianza**: 0.78
# - **Lift**: 1.00
# - **Interpretación**: Si una persona tiene asma, hay una confianza del 77.78% de que también no sobrevivió. El lift de 1.00 indica que esta relación es 1.00 veces más probable que si los hechos fueran independientes.
